# %%
import tweepy
from textblob import TextBlob

consumer_key = 'fmPm8JBwfNSLZ9QhOYjHnNFWL'
consumer_secret = 'R3DQ5ZU5t9ZnjcqFM0hZkIpbfr9N86Uxb0oLIVDhAvey7GylKU'

access_token = '969576483252523009-0thkiwczudf4Xqy2jYbQksrMLS7byoT'
access_token_secret = 'XUED6OQmwz2zf8cBHvekUSS05n0hqDMKmel5Cs7oD5rOp'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search('trump')
for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# Media outlets like MSNBC, NBC, CNN, ABC, CBS, and others tarred yourselves.  You sold the little credibility you al… https://t.co/57TxF0cYZx
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# Everyone who enabled Trump — doctors, lawyers, Republican legislators — should be held accountable https://t.co/VDJ3FN4kfV
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ChatByCC: @realDonaldTrump Contrary to the democrats &amp; fake news—Legal Immigrants do not like illegal aliens either.
#
# All Americans ex…
# Sentiment(polarity=-0.5, subjectivity=0.75)
# RT @DisavowTrump20: BREAKING: Speaker Nancy Pelosi has rejected an offer by President Trump to provide temporary protections for DACA in ex…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @MSNBC: Emily Jane Fox, senior reporter for Vanity Fair, tells Rachel Maddow that Michael Cohen has a document proving that President Tr…
# Sentiment(polarity=0.7, subjectivity=0.9)
# @realDonaldTrump Trump often portrays himself as a savior of the working class who will "protect your job." But ana… https://t.co/UnZ6BZAu5p
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DeplorableChoir: In 2013 Chuck Schumer voted for 350 miles of border wall.
#
# Today they have shut the government down for 234 miles.
#
# T…
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# #SNL: Watch Alec Baldwin’s Trump end the government shutdown with ‘Deal or No Deal’ https://t.co/WNajDnsndP https://t.co/RKN1A5Ov3I
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Blacklace40: This tweet shows just how delusional Trump is. He's living in the past more &amp; more as the stress of being POTUS &amp; possible…
# Sentiment(polarity=0.25, subjectivity=0.4166666666666667)
# RT @marklevinshow: This is the kind of insanity MSNBC airs https://t.co/TVBwEhj7Wk
# Sentiment(polarity=0.6, subjectivity=0.9)
# RT @angxxe_: Y’all couldn’t tell me Trump was in Jamaica? https://t.co/7keiYUKyZD
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SassyKadiK: I love the fact that Ann Coulter is attacking Trump.
# Division is an added bonus.
# Sentiment(polarity=0.5, subjectivity=0.6)
# RT @DFBHarvard: Ann Coulter pans Trump's immigration compromise https://t.co/w9lEhQi0Dl
#
# Ann, I admire your passion, BUT there are some rea…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Thank you President Trump. Please continue to PRAY FOR PRESIDENT TRUMP, HIS FAMILY, HIS ADMINISTRATION &amp; USA. https://t.co/dHDsGlrtPO
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @girlsreallyrule: Do we really need to parallel women just doing their jobs with "Furies" who were born of a castrated man to take venge…
# Sentiment(polarity=0.1, subjectivity=0.1)
